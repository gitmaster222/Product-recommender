# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame 
import nltk

from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from scipy.spatial.distance import cosine
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

import re
import string
from wordcloud import WordCloud, STOPWORDS
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("C:/Users/Admin/Desktop/Amazon-Product-Recommender-System-master/Recommender System/reviewsWithHeader.csv")

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['asin', 'overall', 'reviewText', 'reviewTime', 'reviewerID',
#        'reviewerName', 'summary', 'unixReviewTime', 'helpful', 'total'],
#       dtype='object')
# (278677, 10)

# %% [markdown]
# ### Product based CF

# %%
count = df.groupby("asin", as_index=False).count()
mean = df.groupby("asin", as_index=False).mean()

dfMerged = pd.merge(df, count, how='right', on=['asin'])
dfMerged
# Out:
#               asin  overall_x  \
# 0            31887          5
# 1            31887          5
# 2            31887          5
# 3            31887          5
# 4            31887          5
# 5            31887          4
# 6            31887          5
# 7            31887          5
# 8            31887          4
# 9            31887          5
# 10           31887          5
# 11           31887          5
# 12           31887          5
# 13           31887          5
# 14           31887          5
# 15           31887          3
# 16           31887          5
# 17           31887          1
# 18           31887          5
# 19           31887          5
# 20           31887          5
# 21           31887          5
# 22           31887          4
# 23       123456479          5
# 24       123456479          5
# 25       123456479          5
# 26       123456479          3
# 27       123456479          3
# 28       123456479          4
# 29      1608299953          5
# ...            ...        ...
# 278647  B00KA602SY          5
# 278648  B00KCWMG5S          2
# 278649  B00KCWMG5S          4
# 278650  B00KCWMG5S          3
# 278651  B00KCWMG5S          1
# 278652  B00KCWMG5S          2
# 278653  B00KF9180W          5
# 278654  B00KF9180W          5
# 278655  B00KF9180W          5
# 278656  B00KF9180W          5
# 278657  B00KF9180W          4
# 278658  B00KF9180W          5
# 278659  B00KF9180W          5
# 278660  B00KF9180W          5
# 278661  B00KF9180W          5
# 278662  B00KF9180W          4
# 278663  B00KGCLROK          2
# 278664  B00KGCLROK          5
# 278665  B00KGCLROK          5
# 278666  B00KGCLROK          5
# 278667  B00KGCLROK          5
# 278668  B00KKXCJQU          5
# 278669  B00KKXCJQU          5
# 278670  B00KKXCJQU          5
# 278671  B00KKXCJQU          5
# 278672  B00KKXCJQU          5
# 278673  B00KKXCJQU          5
# 278674  B00KKXCJQU          5
# 278675  B00KKXCJQU          5
# 278676  B00KKXCJQU          5
#
#                                              reviewText_x reviewTime_x  \
# 0       This is a great tutu and at a really great pri...  02 12, 2011
# 1       I bought this for my 4 yr old daughter for dan...  01 19, 2013
# 2       What can I say... my daughters have it in oran...   01 4, 2013
# 3       We bought several tutus at once, and they are ...  04 27, 2014
# 4       Thank you Halo Heaven great product for Little...  03 15, 2014
# 5       I received this today and I'm not a fan of it ...  03 31, 2014
# 6       Bought this as a backup to the regular ballet ...   05 3, 2014
# 7       Great tutu for a great price. It isn't a &#34;...  12 23, 2012
# 8       My daughter liked this, and it with her costum...  11 10, 2013
# 9       For what I paid for two tutus is unbeatable an...   10 7, 2012
# 10      Wonder my niece wears it every single day, yel...   01 2, 2014
# 0       A1KLRMWW2FWPL4                       Amazon Customer "cameramom"
# 1       A2G5TCU2WDFZ65                                   Amazon Customer
# 2       A1RLQXYNCMWRWN                                            Carola
# 3        A8U3FAMSJVHS5                                           Caromcg
# 4       A3GEOILWLK86XM                                                CJ
# 5        A27UF1MSF3DB2                                    C-Lo "Cynthia"
# 6       A16GFPNVF4Y816                                      design maven
# 7       A2M2APVYIB2U6K                                          Jamie P.
# 8       A1NJ71X3YPQNQ9                                           JBerger
# 9        A3EERSWHAI6SO       Jeffrey Hollingshead "Jillian hollingshead"
# 10       AX1QE6IR7CHXM                                                JJ
# 11      A2A2WZYLU528RO                                      Julie Gayler
# 12      A391EXIT5TFP72                                     Lisbeth Starr
# 13      A34ATJR9KFIXL9                                            Maudy1
# 14       AJ6B83I4YJHYW                                          M. Davis
# 15      A26A4KKLAVTMCC                                         Moonlight
# 16      A1MXJVYXE2QU6H                         Mother Goose "WI Grandma"
# 17      A2XJ13PIXVJFJH                               Myra MLH "Myra MLH"
# 18      A287XY94U7JDM8                                           Natasha
# 19      A1JR9KKF6UKUWW                                     Queens Meadow
# 20      A2SX7X8QGQVCJU                                           Shannon
# 21      A2Q6UWR5PBHTJS                                   Sylvia "Sylvia"
# 22       AJZPHJR944IBB                                V's Mommy in Mass.
# 23      A2WNN1DQVL4LH5                                          Caddycat
# 24      A1ZPOCG2ST2CY3                                       Deedee King
# 25      A1WDJIFL2F4QJA                                             Eddie
# 26      A3RB1JA72Z0TUN                                          Elena M.
# 27      A1JC50F14SLAEV                                              Mada
# 28       A8WD29DKN8ZC3                                         Shopper22
# 29      A1F7YU6O5RU432                                    Angela Streiff
# ...                ...                                               ...
# 278647   ANNHM5C3DX72Q                                    Tracey Simmons
# 278648  A2FENE35P9Z592                                            Amanda
# 278649    AODACROYFBAY                                   Denise M Nelson
# 278650  A3O26N290U3VI0                                            Khouri
# 278651  A15WDJOU6B9FLQ                               L. Atwood "Bothell"
# 278652   AG5N21TGDQWRJ                                       Lori Mohler
# 278653  A12DQZKRKTNF5E                                       Andrea Polk
# 278654  A25C2M3QF9G7OQ                                            Comdet
# 278655   ABDR6IJ93HFIO                                   Daisy "Daisy S"
# 278656  A3BFDEBT5IV4UN  Dianne E. Socci-Tetro "Never Judge a Book by ...
# 278657  A1EVV74UQYVKRY                                           K. Groh
# 278658   ABUE0ALHKWKHC                                              Kiwi
# 278659  A1PI8VBCXXSGC7                                              Lynn
# 278660  A2XX2A4OJCDNLZ                               RatherLiveInKeyWest
# 278661  A2YKWYC3WQJX5J             Shannon Lastowski "Queen of Caffeine"
# 278662  A3UJRNI8UR4871                               Wulfstan "wulfstan"
# 278663  A34BZM6S9L7QI4                       Candy Cane "Is it just me?"
# 278664   A4WEZJOIZIV4U        Chuck Bittner "Disabled comedian & gamer!"
# 278665  A25C2M3QF9G7OQ                                            Comdet
# 278666   ACJT8MUC0LRF0                                         D. Fowler
# 278667  A2NOW4U7W3F7RI                                               rpv
# 278668  A1W415JP5WEAJK                                            Alex S
# 278669   AX05DBU8IRUWY                                        C. Schmidt
# 278670   AEL6CQNQXONBX                                    Cute Chihuahua
# 278671   ACJT8MUC0LRF0                                         D. Fowler
# 278672  A2DG63DN704LOI                                            ESlayd
# 278673  A1EVV74UQYVKRY                                           K. Groh
# 278674  A1UQBFCERIP7VJ                                    Margaret Picky
# 278675  A22CW0ZHY3NJH8                                            Noname
# 278676  A30VWT3R25QAVD          THE-DEADLY-DOG "Living and Loving Life."
#
#                                                 summary_x  unixReviewTime_x  \
# 0                           Great tutu-  not cheaply made        1297468800
# 1                                             Very Cute!!        1358553600
# 2                                I have buy more than one        1357257600
# 3                                        Adorable, Sturdy        1398556800
# 4                                 Grammy's Angels Love it        1394841600
# 5                                                 It's ok        1396224000
# 6              Great for dress-up and for ballet practice        1399075200
# 7                                             Great value        1356220800
# 8                                                    Good        1384041600
# 9                          WOW !! ..is all I have to say!        1349568000
# 10                          Wonderful and great shipping.        1388620800
# 11                                     Excellent quality!        1391040000
# 12                                        Wonderful tutu!        1321056000
# 13                                             Great Tutu        1361664000
# 14                           Great tutu for little girls!        1372636800
# 15                                  Came apart in 2weeks!        1395273600
# 16                                               So cute!        1367020800
# 17                                       Never GOT IT....        1399852800
# 18                                             Nice skirt        1387843200
# 19                         must have for a fairy princess        1359504000
# 20                                   My daughter loved it        1351036800
# 21                                                 Sassy!        1358553600
# 22                      Practically Perfect in every way!        1365552000
# 23                                   Breathtaking 5 Stars        1383782400
# 24                                              VERY NICE        1390089600
# 25                           Amazing so many compartments        1348444800
# 26                                  Arrived with a defect        1387411200
# 27                    Nice Size But Drawers Are A Concern        1399852800
# 28                                      Great jewelry box        1388102400
# 29      Suggest getting this 1 level at a time, so you...        1365465600
# ...                                                   ...               ...
# 278647                                          Very nice        1403395200
# 278648                                        Teeny pants        1405814400
# 278649                                     fabric is thin        1402012800
# 278650                                  so, this is weird        1404691200
# 278651                                            Stained        1403481600
# 278652                                     just too small        1401926400
# 278653           Quality set with multiple configurations        1403827200
# 278654  I&#8217;m ready for another frigid blast (or a...        1402099200
# 278655  Wonderful for one who is outdoors in cold weat...        1401840000
# 278656  Look Mom I'm a Ninja...No, I'm a Motorcycle  M...        1402876800
# 278657                   Great for Winter or Chilly Walks        1402876800
# 278658        Nice soft protection from the elements.....        1402272000
# 278659  Love that my ears have two layers of protectio...        1402617600
# 278660  Balaclava 2 Pack - Black - Tan - 100% Polyeste...        1402617600
# 278661                     Fits under even a tight helmet        1403308800
# 278662                               Lightweight & useful        1402272000
# 278663                               Wanted to love these        1403308800
# 278664   My stepmother was impressed with the extra grip.        1404345600
# 278665     A bit fussy to get on, but they work very well        1403395200
# 278666  Very nice, comfortable non-slip socks for yoga...        1404518400
# 278667                                              Cozy!        1403568000
# 278668                            Even Husbands can do it        1402272000
# 278669                                    Not for squares        1405641600
# 278670  Can be used for organization but they are grea...        1402617600
# 278671             End of my packing nightmare system ...        1402272000
# 278672     These have literally changed the way I travel!        1403568000
# 278673                       Wonderful for Better Packing        1403740800
# 278674               Convenient, lightweight, and durable        1402185600
# 278675                   Holds Up Well In Real World Test        1404691200
# 278676  Don't Travel? Still Way too Useful for 'Averag...        1403481600
#
#         helpful_x  total_x  overall_y  reviewText_y  reviewTime_y  \
# 0               0        0         23            23            23
# 1               0        0         23            23            23
# 2               0        0         23            23            23
# 3               0        0         23            23            23
# 4               0        0         23            23            23
# 5               0        0         23            23            23
# 6               0        0         23            23            23
# 7               0        0         23            23            23
# 8               0        0         23            23            23
# 9               7        8         23            23            23
# 10              0        0         23            23            23
# 11              0        0         23            23            23
# 12              0        0         23            23            23
# 13              1        1         23            23            23
# 14              0        0         23            23            23
# 15              0        0         23            23            23
# 16              0        0         23            23            23
# 17              0        0         23            23            23
# 18              0        0         23            23            23
# 19              0        0         23            23            23
# 20              0        0         23            23            23
# 21              0        0         23            23            23
# 22              1        2         23            23            23
# 23              1        1          6             6             6
# 24              0        1          6             6             6
# 25              1        2          6             6             6
# 26              0        0          6             6             6
# 27              0        0          6             6             6
# 28              0        0          6             6             6
# 29              0        0         13            13            13
# ...           ...      ...        ...           ...           ...
# 278647          0        0          6             6             6
# 278648          0        0          5             5             5
# 278649          2        2          5             5             5
# 278650          0        0          5             5             5
# 278651          1        1          5             5             5
# 278652          0        0          5             5             5
# 278653          1        1         10            10            10
# 278654          1        1         10            10            10
# 278655          2        3         10            10            10
# 278656          4        5         10            10            10
# 278657          4        5         10            10            10
# 278658          4        7         10            10            10
# 278659          5        6         10            10            10
# 278660          2        3         10            10            10
# 278661          7        8         10            10            10
# 278662          2        3         10            10            10
# 278663          1        1          5             5             5
# 278664          0        0          5             5             5
# 278665          0        0          5             5             5
# 278666          1        1          5             5             5
# 278667          0        0          5             5             5
# 278668          1        1          9             9             9
# 278669          0        0          9             9             9
# 278670          2        2          9             9             9
# 278671          1        1          9             9             9
# 278672          0        1          9             9             9
# 278673          0        0          9             9             9
# 278674          1        1          9             9             9
# 278675          2        2          9             9             9
# 278676          0        1          9             9             9
#
#         reviewerID_y  reviewerName_y  summary_y  unixReviewTime_y  helpful_y  \
# 0                 23              23         23                23         23
# 1                 23              23         23                23         23
# 2                 23              23         23                23         23
# 3                 23              23         23                23         23
# 4                 23              23         23                23         23
# 5                 23              23         23                23         23
# 6                 23              23         23                23         23
# 7                 23              23         23                23         23
# 8                 23              23         23                23         23
# 9                 23              23         23                23         23
# 10                23              23         23                23         23
# 11                23              23         23                23         23
# 12                23              23         23                23         23
# 13                23              23         23                23         23
# 14                23              23         23                23         23
# 15                23              23         23                23         23
# 16                23              23         23                23         23
# 17                23              23         23                23         23
# 18                23              23         23                23         23
# 19                23              23         23                23         23
# 20                23              23         23                23         23
# 21                23              23         23                23         23
# 22                23              23         23                23         23
# 23                 6               6          6                 6          6
# 24                 6               6          6                 6          6
# 25                 6               6          6                 6          6
# 26                 6               6          6                 6          6
# 27                 6               6          6                 6          6
# 28                 6               6          6                 6          6
# 29                13              13         13                13         13
# ...              ...             ...        ...               ...        ...
# 278647             6               6          6                 6          6
# 278648             5               5          5                 5          5
# 278649             5               5          5                 5          5
# 278650             5               5          5                 5          5
# 278651             5               5          5                 5          5
# 278652             5               5          5                 5          5
# 278653            10              10         10                10         10
# 278654            10              10         10                10         10
# 278655            10              10         10                10         10
# 278656            10              10         10                10         10
# 278657            10              10         10                10         10
# 278658            10              10         10                10         10
# 278659            10              10         10                10         10
# 278660            10              10         10                10         10
# 278661            10              10         10                10         10
# 278662            10              10         10                10         10
# 278663             5               5          5                 5          5
# 278664             5               5          5                 5          5
# 278665             5               5          5                 5          5
# 278666             5               5          5                 5          5
# 278667             5               5          5                 5          5
# 278668             9               9          9                 9          9
# 278669             9               9          9                 9          9
# 278670             9               9          9                 9          9
# 278671             9               9          9                 9          9
# 278672             9               9          9                 9          9
# 278673             9               9          9                 9          9
# 278674             9               9          9                 9          9
# 278675             9               9          9                 9          9
# 278676             9               9          9                 9          9
#
#         total_y
# 0            23
# 1            23
# 2            23
# 3            23
# 4            23
# 5            23
# 6            23
# 7            23
# 8            23
# 9            23
# 10           23
# 11           23
# 12           23
# 13           23
# 14           23
# 15           23
# 16           23
# 17           23
# 18           23
# 19           23
# 20           23
# 21           23
# 22           23
# 23            6
# 24            6
# 25            6
# 26            6
# 27            6
# 28            6
# 29           13
# ...         ...
# 278647        6
# 278648        5
# 278649        5
# 278650        5
# 278651        5
# 278652        5
# 278653       10
# 278654       10
# 278655       10
# 278656       10
# 278657       10
# 278658       10
# 278659       10
# 278660       10
# 278661       10
# 278662       10
# 278663        5
# 278664        5
# 278665        5
# 278666        5
# 278667        5
# 278668        9
# 278669        9
# 278670        9
# 278671        9
# 278672        9
# 278673        9
# 278674        9
# 278675        9
# 278676        9
#
# [278677 rows x 19 columns]

# %%
#rename column
dfMerged["totalReviewers"] = dfMerged["reviewerID_y"]
dfMerged["overallScore"] = dfMerged["overall_x"]
dfMerged["summaryReview"] = dfMerged["summary_x"]

dfNew = dfMerged[['asin','summaryReview','overallScore',"totalReviewers"]]

# %% [markdown]
# Selecting products which have more than 50 reviews

# %%
dfMerged = dfMerged.sort_values(by='totalReviewers', ascending=False)
dfCount = dfMerged[dfMerged.totalReviewers >= 100]
dfCount
# Out:
#               asin  overall_x  \
# 161700  B005LERHD8          4
# 161269  B005LERHD8          4
# 161280  B005LERHD8          4
# 161279  B005LERHD8          1
# 161278  B005LERHD8          5
# 161277  B005LERHD8          4
# 161276  B005LERHD8          4
# 161275  B005LERHD8          5
# 161274  B005LERHD8          4
# 161273  B005LERHD8          1
# 161272  B005LERHD8          4
# 161271  B005LERHD8          5
# 161270  B005LERHD8          4
# 161268  B005LERHD8          5
# 161282  B005LERHD8          5
# 161267  B005LERHD8          5
# 161266  B005LERHD8          5
# 161265  B005LERHD8          5
# 161422  B005LERHD8          5
# 161423  B005LERHD8          5
# 161424  B005LERHD8          5
# 161425  B005LERHD8          4
# 161426  B005LERHD8          5
# 161427  B005LERHD8          4
# 161428  B005LERHD8          5
# 161429  B005LERHD8          3
# 161281  B005LERHD8          4
# 161283  B005LERHD8          5
# 161310  B005LERHD8          5
# 161428                                           Precious        1398384000
# 161429                                   Cute Owl Pendant        1390780800
# 161281                           Fun, sparkly, Unique Owl        1375747200
# 161283                                        Really cute        1391040000
# 161310                                        Super cute!        1390262400
# 161297                                           Perfect!        1355788800
# ...                                                   ...               ...
# 113990                                            Perfect        1371427200
# 114040                                          Too small        1401062400
# 114041                                              CROCS        1401580800
# 114043                                   Everyday sandal.        1370390400
# 114044                                          excellent        1376524800
# 114045                    Exactly what I was looking for!        1338422400
# 114047                                Comfortable all day        1362787200
# 114022          crocs womens sexi flip sandal black/black        1372982400
# 114030                                     Cute and comfy        1358553600
# 114029                                          Too short        1403740800
# 114028                                  very comfortable!        1369008000
# 114027                   Comfortable but not true to size        1393977600
# 114026                                         Comfy Croc        1398211200
# 114025                                Love these sandals!        1389916800
# 114024                                            Like it        1366243200
# 114023                                   excellent crocs!        1362355200
# 114042                                Not what I expected        1362096000
# 114053                            Kind of weird to put on        1398384000
# 114031                                 I love these shoes        1365724800
# 114080                                       AWSOME crocs        1376524800
# 114032                                   flimsy and tight        1371772800
# 114089                                      Great Sandal!        1370044800
# 114087                             Better than flip flops        1363824000
# 114086                               These are super cute        1368489600
# 114085  Thank GOD Crocs made sandals for "the rest of us"        1370390400
# 114084                     cute, but not good for my feet        1377820800
# 114083                                       Crocs Sandal        1389052800
# 114082                            Minimal Yet Comfortable        1351036800
# 114081                                          Excellent        1380153600
# 114088                             Simple Yet Comfortable        1402531200
#
#         helpful_x  total_x                        ...                          \
# 161700          0        0                        ...
# 161269          0        0                        ...
# 161280          0        0                        ...
# 161279          0        0                        ...
# 161278          0        0                        ...
# 161277          0        0                        ...
# 161276          0        0                        ...
# 161275          0        0                        ...
# 161274          0        0                        ...
# 161273          0        0                        ...
# 161272          0        0                        ...
# 161271          0        0                        ...
# 161270          0        0                        ...
# 161268          0        0                        ...
# 161282          0        0                        ...
# 161267          0        0                        ...
# 161266          0        0                        ...
# 161265          0        0                        ...
# 161422          0        0                        ...
# 161423          0        0                        ...
# 161424          0        0                        ...
# 161425          0        0                        ...
# 161426          0        0                        ...
# 161427          0        0                        ...
# 161428          0        0                        ...
# 161429          0        0                        ...
# 161281          1        1                        ...
# 161283          0        0                        ...
# 161310          0        0                        ...
# 161297          0        0                        ...
# ...           ...      ...                        ...
# 113990          0        0                        ...
# 114040          0        0                        ...
# 114041          0        0                        ...
# 114043          0        0                        ...
# 114044          0        0                        ...
# 114045          0        0                        ...
# 114047          1        2                        ...
# 114022          0        0                        ...
# 114030          0        0                        ...
# 114029          0        0                        ...
# 114028          0        0                        ...
# 114027          0        0                        ...
# 114026          0        0                        ...
# 114025          0        0                        ...
# 114024          0        0                        ...
# 114023          0        1                        ...
# 114042          0        0                        ...
# 114053          0        0                        ...
# 114031          0        0                        ...
# 114080          0        0                        ...
# 114032          2        2                        ...
# 114089          0        0                        ...
# 114087          0        0                        ...
# 114086          0        0                        ...
# 114085         34       40                        ...
# 114084          0        0                        ...
# 114083          0        0                        ...
# 114082          0        0                        ...
# 114081          0        0                        ...
# 114088          0        0                        ...
#
#         reviewTime_y  reviewerID_y  reviewerName_y  summary_y  \
# 161700           441           441             441        441
# 161269           441           441             441        441
# 161280           441           441             441        441
# 161279           441           441             441        441
# 161278           441           441             441        441
# 161277           441           441             441        441
# 161276           441           441             441        441
# 161275           441           441             441        441
# 161274           441           441             441        441
# 161273           441           441             441        441
# 161272           441           441             441        441
# 161271           441           441             441        441
# 161270           441           441             441        441
# 161268           441           441             441        441
# 161282           441           441             441        441
# 161267           441           441             441        441
# 161266           441           441             441        441
# 161265           441           441             441        441
# 161422           441           441             441        441
# 161423           441           441             441        441
# 161424           441           441             441        441
# 161425           441           441             441        441
# 161426           441           441             441        441
# 161427           441           441             441        441
# 161428           441           441             441        441
# 161429           441           441             441        441
# 161281           441           441             441        441
# 161283           441           441             441        441
# 161310           441           441             441        441
# 161297           441           441             441        441
# ...              ...           ...             ...        ...
# 113990           100           100             100        100
# 114040           100           100             100        100
# 114041           100           100             100        100
# 114043           100           100             100        100
# 114044           100           100             100        100
# 114045           100           100             100        100
# 114047           100           100             100        100
# 114022           100           100             100        100
# 114030           100           100             100        100
# 114029           100           100             100        100
# 114028           100           100             100        100
# 114027           100           100             100        100
# 114026           100           100             100        100
# 114025           100           100             100        100
# 114024           100           100             100        100
# 114023           100           100             100        100
# 114042           100           100             100        100
# 114053           100           100             100        100
# 114031           100           100             100        100
# 114080           100           100             100        100
# 114032           100           100             100        100
# 114089           100           100             100        100
# 114087           100           100             100        100
# 114086           100           100             100        100
# 114085           100           100             100        100
# 114084           100           100             100        100
# 114083           100           100             100        100
# 114082           100           100             100        100
# 114081           100           100             100        100
# 114088           100           100             100        100
#
#         unixReviewTime_y  helpful_y  total_y  totalReviewers  overallScore  \
# 161700               441        441      441             441             4
# 161269               441        441      441             441             4
# 161280               441        441      441             441             4
# 161279               441        441      441             441             1
# 161278               441        441      441             441             5
# 161277               441        441      441             441             4
# 161276               441        441      441             441             4
# 161275               441        441      441             441             5
# 161274               441        441      441             441             4
# 161273               441        441      441             441             1
# 161272               441        441      441             441             4
# 161271               441        441      441             441             5
# 161270               441        441      441             441             4
# 161268               441        441      441             441             5
# 161282               441        441      441             441             5
# 161267               441        441      441             441             5
# 161266               441        441      441             441             5
# 161265               441        441      441             441             5
# 161422               441        441      441             441             5
# 161423               441        441      441             441             5
# 161424               441        441      441             441             5
# 161425               441        441      441             441             4
# 161426               441        441      441             441             5
# 161427               441        441      441             441             4
# 161428               441        441      441             441             5
# 161429               441        441      441             441             3
# 161281               441        441      441             441             4
# 161283               441        441      441             441             5
# 161310               441        441      441             441             5
# 161297               441        441      441             441             5
# ...                  ...        ...      ...             ...           ...
# 113990               100        100      100             100             5
# 114040               100        100      100             100             2
# 114041               100        100      100             100             1
# 114043               100        100      100             100             4
# 114044               100        100      100             100             5
# 114045               100        100      100             100             5
# 114047               100        100      100             100             5
# 114022               100        100      100             100             5
# 114030               100        100      100             100             5
# 114029               100        100      100             100             2
# 114028               100        100      100             100             4
# 114027               100        100      100             100             3
# 114026               100        100      100             100             4
# 114025               100        100      100             100             5
# 114024               100        100      100             100             5
# 114023               100        100      100             100             5
# 114042               100        100      100             100             3
# 114053               100        100      100             100             4
# 114031               100        100      100             100             5
# 114080               100        100      100             100             5
# 114032               100        100      100             100             2
# 114089               100        100      100             100             5
# 114087               100        100      100             100             5
# 114086               100        100      100             100             5
# 114085               100        100      100             100             5
# 114084               100        100      100             100             2
# 114083               100        100      100             100             5
# 114082               100        100      100             100             5
# 114081               100        100      100             100             5
# 114088               100        100      100             100             5
#
#                                             summaryReview
# 161700                                            It's ok
# 161269                                        Really Cute
# 161280                                        Very pretty
# 161279                               Not worth your money
# 161278                                     Really pretty!
# 161277                                               Cute
# 161276           nice except the eyes are a little creepy
# 161275                          nice quality. Nice length
# 161274                  Very cute, larger than it appears
# 161273                                              Cheap
# 161272                                               love
# 161271                                           loved it
# 161270                                           Nice set
# 161268                                 Very nice necklace
# 161282                                       Owl Necklace
# 161267  Vintage, Retro Colorful Crystal Owl Pendant an...
# 161266                              GOES WITH ANOTHER ONE
# 161265                                        Really cute
# 161422                              Golden Owl is Awesome
# 161423                                           loved it
# 161424                           Beautiful looking pieces
# 161425                                              Nice.
# 161426                                              CUTE!
# 161427                                               Cute
# 161428                                           Precious
# 161429                                   Cute Owl Pendant
# 161281                           Fun, sparkly, Unique Owl
# 161283                                        Really cute
# 161310                                        Super cute!
# 161297                                           Perfect!
# ...                                                   ...
# 113990                                            Perfect
# 114040                                          Too small
# 114041                                              CROCS
# 114043                                   Everyday sandal.
# 114044                                          excellent
# 114045                    Exactly what I was looking for!
# 114047                                Comfortable all day
# 114022          crocs womens sexi flip sandal black/black
# 114030                                     Cute and comfy
# 114029                                          Too short
# 114028                                  very comfortable!
# 114027                   Comfortable but not true to size
# 114026                                         Comfy Croc
# 114025                                Love these sandals!
# 114024                                            Like it
# 114023                                   excellent crocs!
# 114042                                Not what I expected
# 114053                            Kind of weird to put on
# 114031                                 I love these shoes
# 114080                                       AWSOME crocs
# 114032                                   flimsy and tight
# 114089                                      Great Sandal!
# 114087                             Better than flip flops
# 114086                               These are super cute
# 114085  Thank GOD Crocs made sandals for "the rest of us"
# 114084                     cute, but not good for my feet
# 114083                                       Crocs Sandal
# 114082                            Minimal Yet Comfortable
# 114081                                          Excellent
# 114088                             Simple Yet Comfortable
#
# [13379 rows x 22 columns]

# %% [markdown]
# ### Grouping all the summary Reviews by product ID

# %%
dfProductReview = df.groupby("asin", as_index=False).mean()
ProductReviewSummary = dfCount.groupby("asin")["summaryReview"].apply(list)
ProductReviewSummary = pd.DataFrame(ProductReviewSummary)
ProductReviewSummary.to_csv("ProductReviewSummary.csv")

# %%
dfProductReview
# Out:
#              asin   overall  unixReviewTime    helpful      total
# 0       123456479  4.166667    1.382947e+09   0.333333   0.666667
# 1      1608299953  4.307692    1.307637e+09  27.769231  30.230769
# 2      1617160377  4.625000    1.321078e+09   4.625000   5.062500
# 3           31887  4.608696    1.370064e+09   0.391304   0.478261
# 23019  B00JX3UGGI  4.142857    1.404136e+09   1.857143   2.000000
# 23020  B00JZSDW8A  4.833333    1.401149e+09   4.166667   4.333333
# 23021  B00K0352PU  4.166667    1.403280e+09   2.500000   2.833333
# 23022  B00K035Y08  4.666667    1.403957e+09   0.166667   0.333333
# 23023  B00K0BPFY0  4.600000    1.404415e+09   1.000000   1.200000
# 23024  B00K551QR6  3.500000    1.404720e+09   1.666667   1.666667
# 23025  B00K5T4NHC  4.857143    1.403642e+09   1.000000   1.000000
# 23026  B00K8J06CK  4.600000    1.404052e+09   0.600000   0.800000
# 23027  B00KA2X4QK  4.600000    1.404760e+09   0.000000   0.000000
# 23028  B00KA602SY  3.833333    1.404144e+09   0.000000   0.166667
# 23029  B00KCWMG5S  2.400000    1.403585e+09   0.600000   0.600000
# 23030  B00KF9180W  4.800000    1.402661e+09   3.200000   4.200000
# 23031  B00KGCLROK  4.400000    1.403827e+09   0.400000   0.400000
# 23032  B00KKXCJQU  5.000000    1.403386e+09   0.777778   1.000000
#
# [23033 rows x 5 columns]

# %% [markdown]
# ### create dataframe with certain columns

# %%
df3 = pd.read_csv("ProductReviewSummary.csv")
df3 = pd.merge(df3, dfProductReview, on="asin", how='inner')

# %%
df3 = df3[['asin','summaryReview','overall']]

# %% [markdown]
# ### Text Cleaning - Summary column

# %%
#function for tokenizing summary
regEx = re.compile('[^a-z]+')
def cleanReviews(reviewText):
    reviewText = reviewText.lower()
    reviewText = regEx.sub(' ', reviewText).strip()
    return reviewText

# %%
#reset index and drop duplicate rows
df3["summaryClean"] = df3["summaryReview"].apply(cleanReviews)
df3 = df3.drop_duplicates(['overall'], keep='last')
df3 = df3.reset_index()

# %%
reviews = df3["summaryClean"] 
countVector = CountVectorizer(max_features = 300, stop_words='english') 
transformedReviews = countVector.fit_transform(reviews) 

dfReviews = DataFrame(transformedReviews.A, columns=countVector.get_feature_names())
dfReviews = dfReviews.astype(int)

# %%
#save 
dfReviews.to_csv("dfReviews.csv")

# %%
# First let's create a dataset called X
X = np.array(dfReviews)
 # create train and test
tpercent = 0.9
tsize = int(np.floor(tpercent * len(dfReviews)))
dfReviews_train = X[:tsize]
dfReviews_test = X[tsize:]
#len of train and test
lentrain = len(dfReviews_train)
lentest = len(dfReviews_test)

# %%
# KNN classifier to find similar products
print(lentrain)
print(lentest)
# Out:
# 80
# 9

# %%
neighbor = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(dfReviews_train)

# Let's find the k-neighbors of each point in object X. To do that we call the kneighbors() function on object X.
distances, indices = neighbor.kneighbors(dfReviews_train)

# %%
#find most related products
for i in range(lentest):
    a = neighbor.kneighbors([dfReviews_test[i]])
    related_product_list = a[1]

    first_related_product = [item[0] for item in related_product_list]
    first_related_product = str(first_related_product).strip('[]')
    first_related_product = int(first_related_product)
    second_related_product = [item[1] for item in related_product_list]
    second_related_product = str(second_related_product).strip('[]')
    second_related_product = int(second_related_product)
    
    print ("Based on product reviews, for ", df3["asin"][lentrain + i] ," average rating is ",df3["overall"][lentrain + i])
    print ("The first similar product is ", df3["asin"][first_related_product] ," average rating is ",df3["overall"][first_related_product])
    print ("The second similar product is ", df3["asin"][second_related_product] ," average rating is ",df3["overall"][second_related_product])
    print ("-----------------------------------------------------------")
# Out:
# Based on product reviews, for  B00BNB3A0W  average rating is  3.4414414414414414
# The first similar product is  B004Z1CZDK  average rating is  3.1923076923076925
# The second similar product is  B0053XF2U2  average rating is  3.8684210526315788
# -----------------------------------------------------------
# Based on product reviews, for  B00CIBCJ62  average rating is  4.2164179104477615
# The first similar product is  B004R1II48  average rating is  4.055555555555555
# The second similar product is  B007WAEBPQ  average rating is  4.333333333333333
# -----------------------------------------------------------
# Based on product reviews, for  B00CKGB85I  average rating is  4.066666666666666
# The first similar product is  B004R1II48  average rating is  4.055555555555555
# The second similar product is  B0074T7TY0  average rating is  4.255474452554744
# -----------------------------------------------------------
# Based on product reviews, for  B00CN47GXA  average rating is  3.4634146341463414
# The first similar product is  B007WAU1VY  average rating is  3.551470588235294
# The second similar product is  B007WAEBPQ  average rating is  4.333333333333333
# -----------------------------------------------------------
# Based on product reviews, for  B00D1MR8YU  average rating is  3.83739837398374
# The first similar product is  B004R1II48  average rating is  4.055555555555555
# The second similar product is  B0053XF2U2  average rating is  3.8684210526315788
# -----------------------------------------------------------
# Based on product reviews, for  B00DMWQK0W  average rating is  4.298076923076923
# The first similar product is  B008RUOCJU  average rating is  3.973684210526316
# The second similar product is  B0078FXHNM  average rating is  4.26056338028169
# -----------------------------------------------------------
# Based on product reviews, for  B00DMWQOYY  average rating is  4.119718309859155
# The first similar product is  B0067GUM2W  average rating is  4.174863387978142
# The second similar product is  B0078FXHNM  average rating is  4.26056338028169
# -----------------------------------------------------------
# Based on product reviews, for  B00DNQIIE8  average rating is  4.228758169934641
# The first similar product is  B0078FXHNM  average rating is  4.26056338028169
# The second similar product is  B0067GUM2W  average rating is  4.174863387978142
# -----------------------------------------------------------
# Based on product reviews, for  B00DQYNS3I  average rating is  4.526315789473684
# The first similar product is  B003YBHF82  average rating is  4.21
# The second similar product is  B000FH4JJQ  average rating is  4.536363636363636
# -----------------------------------------------------------

# %%
print ("Based on product reviews, for ", df3["asin"]," average rating is ",df3["overall"])
print ("The first similar product is ", df3["asin"][first_related_product] ," average rating is ",df3["overall"][first_related_product])
print ("The second similar product is ", df3["asin"][second_related_product] ," average rating is ",df3["overall"][second_related_product])
print ("-----------------------------------------------------------")
# Out:
# Based on product reviews, for  0     B0000ANHST
# 1     B0000C321X
# 2     B00012O12A
# 3     B0001ZNZJM
# 4     B0006LMBJ6
# 5     B0007CKMA4
# 6     B0007QCOTM
# 7     B0007YR8WW
# 8     B0007YVP1W
# 9     B0007YXTOS
# 10    B0008172S4
# 11    B0008EOEPK
# 12    B0009B3IN6
# 13    B000DZUGOM
# 14    B000EIJG0I
# 15    B000FBO0DM
# 16    B000FH4JJQ
# 17    B000GOVRDE
# 18    B000J6ZYL0
# 19    B000KEG4V0
# 20    B000KKTPD8
# 21    B000O32MLI
# 22    B000PH25X8
# 23    B000QW6LE6
# 24    B000T9VK56
# 25    B000XDDERK
# 26    B001188FZC
# 27    B0012QM8IS
# 28    B0013KDS96
# 29    B001AOZVSQ
#          ...
# 59    B0068VM5T4
# 60    B006PGGJOE
# 61    B006SCSOOS
# 62    B0074T7TY0
# 63    B0076R6KY0
# 64    B0078FXHNM
# 65    B007NLX16O
# 66    B007RD9DS8
# 67    B007WA3K4Y
# 68    B007WAEBPQ
# 69    B007WAU1VY
# 70    B007WNWEFC
# 71    B0081IZ3UA
# 72    B0083S18LQ
# 73    B008KK0ZJ8
# 74    B008NCYALM
# 75    B008RUOCJU
# 76    B008WYDP1C
# 77    B008X0EW44
# 78    B009DNWFD0
# 79    B009ZDEXQK
# 80    B00BNB3A0W
# 81    B00CIBCJ62
# 82    B00CKGB85I
# 83    B00CN47GXA
# 84    B00D1MR8YU
# 85    B00DMWQK0W
# 86    B00DMWQOYY
# 87    B00DNQIIE8
# 88    B00DQYNS3I
# Name: asin, Length: 89, dtype: object  average rating is  0     4.487179
# 1     4.263415
# 2     4.153439
# 3     4.472081
# 4     4.258929
# 5     4.297297
# 6     4.656863
# 7     4.005405
# 8     4.360759
# 9     4.375000
# 10    4.266667
# 11    4.559140
# 12    4.445545
# 13    4.563492
# 14    4.594595
# 15    4.586466
# 16    4.536364
# 17    4.390625
# 18    4.194245
# 19    3.679739
# 20    4.272727
# 21    4.513812
# 22    4.206612
# 23    3.961832
# 24    3.840580
# 25    4.446809
# 26    4.466667
# 27    3.871560
# 28    4.781513
# 29    4.289474
#         ...
# 59    4.589552
# 60    4.220238
# 61    4.343137
# 62    4.255474
# 63    4.504587
# 64    4.260563
# 65    4.507937
# 66    3.903226
# 67    4.209424
# 68    4.333333
# 69    3.551471
# 70    4.243655
# 71    4.439252
# 72    3.956522
# 73    4.683230
# 74    3.864865
# 75    3.973684
# 76    4.257028
# 77    3.874126
# 78    3.844660
# 79    4.725490
# 80    3.441441
# 81    4.216418
# 82    4.066667
# 83    3.463415
# 84    3.837398
# 85    4.298077
# 86    4.119718
# 87    4.228758
# 88    4.526316
# Name: overall, Length: 89, dtype: float64
# The first similar product is  B003YBHF82  average rating is  4.21
# The second similar product is  B000FH4JJQ  average rating is  4.536363636363636
# -----------------------------------------------------------

# %% [markdown]
# ### Predicting Review Score

# %%
df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)

n_neighbors = 3
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)

print(classification_report(df5_test_target, knnpreds_test))
# Out:
#              precision    recall  f1-score   support
#
#           3       1.00      1.00      1.00         3
#           4       1.00      1.00      1.00         6
#
# avg / total       1.00      1.00      1.00         9

# %% [markdown]
# ### Accuracy of the model

# %%
print (accuracy_score(df5_test_target, knnpreds_test))
# Out:
# 1.0

# %%
print(mean_squared_error(df5_test_target, knnpreds_test))
# Out:
# 0.0

# %% [markdown]
# ### Predicting Review Score with k = 5

# %%
df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)

n_neighbors = 5
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)
#print (knnpreds_test)

print(classification_report(df5_test_target, knnpreds_test))
# Out:
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         3
#           4       0.67      1.00      0.80         6
#
# avg / total       0.44      0.67      0.53         9
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print (accuracy_score(df5_test_target, knnpreds_test))
# Out:
# 0.6666666666666666

# %%
print(mean_squared_error(df5_test_target, knnpreds_test))
# Out:
# 0.3333333333333333

# %% [markdown]
# ### Predicting reviews with 85, 15 train, test split and k = 5

# %%
# First let's create a dataset called X
X = np.array(dfReviews)
 # create train and test
tpercent = 0.85
tsize = int(np.floor(tpercent * len(dfReviews)))
dfReviews_train = X[:tsize]
dfReviews_test = X[tsize:]
#len of train and test
lentrain = len(dfReviews_train)
lentest = len(dfReviews_test)

# %%
# Next we will instantiate a nearest neighbor object, and call it nbrs. Then we will fit it to dataset X.
neighbor = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(dfReviews_train)

# Let's find the k-neighbors of each point in object X. To do that we call the kneighbors() function on object X.
distances, indices = neighbor.kneighbors(dfReviews_train)

# %%
#find most related products
for i in range(lentest):
    a = neighbor.kneighbors([dfReviews_test[i]])
    related_product_list = a[1]

    first_related_product = [item[0] for item in related_product_list]
    first_related_product = str(first_related_product).strip('[]')
    first_related_product = int(first_related_product)
    second_related_product = [item[1] for item in related_product_list]
    second_related_product = str(second_related_product).strip('[]')
    second_related_product = int(second_related_product)
    
    print ("Based on product reviews, for ", df3["asin"][lentrain + i] ," average rating is ",df3["overall"][lentrain + i])
    print ("The first similar product is ", df3["asin"][first_related_product] ," average rating is ",df3["overall"][first_related_product])
    print ("The second similar product is ", df3["asin"][second_related_product] ," average rating is ",df3["overall"][second_related_product])
    print ("-----------------------------------------------------------")
# Out:
# Based on product reviews, for  B008RUOCJU  average rating is  3.973684210526316
# The first similar product is  B007WAEBPQ  average rating is  4.333333333333333
# The second similar product is  B004R1II48  average rating is  4.055555555555555
# -----------------------------------------------------------
# Based on product reviews, for  B008WYDP1C  average rating is  4.257028112449799
# The first similar product is  B007WA3K4Y  average rating is  4.209424083769633
# The second similar product is  B0083S18LQ  average rating is  3.9565217391304346
# -----------------------------------------------------------
# Based on product reviews, for  B008X0EW44  average rating is  3.874125874125874
# The first similar product is  B007WAEBPQ  average rating is  4.333333333333333
# The second similar product is  B0083S18LQ  average rating is  3.9565217391304346
# -----------------------------------------------------------
# Based on product reviews, for  B009DNWFD0  average rating is  3.8446601941747574
# The first similar product is  B0053XF2U2  average rating is  3.8684210526315788
# The second similar product is  B004R1II48  average rating is  4.055555555555555
# -----------------------------------------------------------
# Based on product reviews, for  B009ZDEXQK  average rating is  4.7254901960784315
# The first similar product is  B000EIJG0I  average rating is  4.594594594594595
# The second similar product is  B001Q5QLP6  average rating is  4.673913043478261
# -----------------------------------------------------------
# Based on product reviews, for  B00BNB3A0W  average rating is  3.4414414414414414
# The first similar product is  B004Z1CZDK  average rating is  3.1923076923076925
# The second similar product is  B0053XF2U2  average rating is  3.8684210526315788
# -----------------------------------------------------------
# Based on product reviews, for  B00CIBCJ62  average rating is  4.2164179104477615
# The first similar product is  B004R1II48  average rating is  4.055555555555555
# The second similar product is  B007WAEBPQ  average rating is  4.333333333333333
# -----------------------------------------------------------
# Based on product reviews, for  B00CKGB85I  average rating is  4.066666666666666
# The first similar product is  B004R1II48  average rating is  4.055555555555555
# The second similar product is  B0074T7TY0  average rating is  4.255474452554744
# -----------------------------------------------------------
# Based on product reviews, for  B00CN47GXA  average rating is  3.4634146341463414
# The first similar product is  B007WAU1VY  average rating is  3.551470588235294
# The second similar product is  B007WAEBPQ  average rating is  4.333333333333333
# -----------------------------------------------------------
# Based on product reviews, for  B00D1MR8YU  average rating is  3.83739837398374
# The first similar product is  B004R1II48  average rating is  4.055555555555555
# The second similar product is  B0053XF2U2  average rating is  3.8684210526315788
# -----------------------------------------------------------
# Based on product reviews, for  B00DMWQK0W  average rating is  4.298076923076923
# The first similar product is  B0078FXHNM  average rating is  4.26056338028169
# The second similar product is  B007WAEBPQ  average rating is  4.333333333333333
# -----------------------------------------------------------
# Based on product reviews, for  B00DMWQOYY  average rating is  4.119718309859155
# The first similar product is  B0067GUM2W  average rating is  4.174863387978142
# The second similar product is  B0078FXHNM  average rating is  4.26056338028169
# -----------------------------------------------------------
# Based on product reviews, for  B00DNQIIE8  average rating is  4.228758169934641
# The first similar product is  B0078FXHNM  average rating is  4.26056338028169
# The second similar product is  B0067GUM2W  average rating is  4.174863387978142
# -----------------------------------------------------------
# Based on product reviews, for  B00DQYNS3I  average rating is  4.526315789473684
# The first similar product is  B003YBHF82  average rating is  4.21
# The second similar product is  B000FH4JJQ  average rating is  4.536363636363636
# -----------------------------------------------------------

# %%
df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)

n_neighbors = 5
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)
#print (knnpreds_test)

print(classification_report(df5_test_target, knnpreds_test))
# Out:
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         6
#           4       0.57      1.00      0.73         8
#
# avg / total       0.33      0.57      0.42        14
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print (accuracy_score(df5_test_target, knnpreds_test))
# Out:
# 0.5714285714285714

# %%
print(mean_squared_error(df5_test_target, knnpreds_test))
# Out:
# 0.42857142857142855

# %% [markdown]
# ### kNN with k = 3, Algorithm = Brute

# %%
neighbor = NearestNeighbors(n_neighbors=3, algorithm='brute').fit(dfReviews_train)

distances, indices = neighbor.kneighbors(dfReviews_train)

# %%
df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)
n_neighbors = 3
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)

print(classification_report(df5_test_target, knnpreds_test))
print ("Accuracy: ",accuracy_score(df5_test_target, knnpreds_test))
print("MSE: ",mean_squared_error(df5_test_target, knnpreds_test))
# Out:
#              precision    recall  f1-score   support
#
#           3       1.00      0.67      0.80         6
#           4       0.80      1.00      0.89         8
#
# avg / total       0.89      0.86      0.85        14
#
# Accuracy:  0.8571428571428571
# MSE:  0.14285714285714285

# %% [markdown]
# ### kNN with k= 5, and Algorithm = KD_Tree

# %%
neighbor = NearestNeighbors(n_neighbors=5, algorithm='kd_tree').fit(dfReviews_train)
distances, indices = neighbor.kneighbors(dfReviews_train)

# %%
df5_train_target = df3["overall"][:lentrain]
df5_test_target = df3["overall"][lentrain:lentrain+lentest]
df5_train_target = df5_train_target.astype(int)
df5_test_target = df5_test_target.astype(int)
n_neighbors = 5
knnclf = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knnclf.fit(dfReviews_train, df5_train_target)
knnpreds_test = knnclf.predict(dfReviews_test)

print(classification_report(df5_test_target, knnpreds_test))
print ("Accuracy: ",accuracy_score(df5_test_target, knnpreds_test))
print("MSE: ",mean_squared_error(df5_test_target, knnpreds_test))
# Out:
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         6
#           4       0.57      1.00      0.73         8
#
# avg / total       0.33      0.57      0.42        14
#
# Accuracy:  0.5714285714285714
# MSE:  0.42857142857142855
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Word correltation based on cluster

# %%
cluster = df.groupby("overall")["summary"].apply(list)
cluster = pd.DataFrame(cluster)
cluster.to_csv("cluster.csv")
cluster1 = pd.read_csv("cluster.csv")
cluster1["summaryClean"] = cluster1["summary"].apply(cleanReviews)

# %% [markdown]
# ### World Clouding for Each Score Group

# %%
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=500,
        max_font_size=30, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))
    
    fig = plt.figure(1, figsize=(8, 8))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
show_wordcloud(cluster1["summaryClean"][0], title = "Review Score One")

# %%
show_wordcloud(cluster1["summaryClean"][1] , title = "Review Score Two")

# %%
show_wordcloud(cluster1["summaryClean"][2], title = "Review Score Three")

# %%
show_wordcloud(cluster1["summaryClean"][3], title = "Review Score Four")

# %%
show_wordcloud(cluster1["summaryClean"][4], title = "Review Score Five")
